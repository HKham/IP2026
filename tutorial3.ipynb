# %%
d = {'user':'bozo', 'pswd':1234}

# %%
d['user']
# Out:
# 'bozo'

# %%
d['pswd']
# Out:
# 1234

# %%
d['user'] = 'clown'
d
# Out:
# {'user': 'clown', 'pswd': 1234}

# %%
d['id'] = 45
d
# Out:
# {'user': 'clown', 'pswd': 1234, 'id': 45}

# %%
d= {'user': 'clown', 'pswd': 1234, 'id': 45}
del d['user']
d
# Out:
# {'pswd': 1234, 'id': 45}

# %%
d.clear()
d
# Out:
# {}

# %%
a= [1,2]
del a[1]
a
# Out:
# [1]

# %%
d = {'user': 'bozo', 'pswd': 1234, 'id': 37}
d.keys()
# Out:
# dict_keys(['user', 'pswd', 'id'])

# %%
d.values()
# Out:
# dict_values(['bozo', 1234, 37])

# %%
d.items()
# Out:
# dict_items([('user', 'bozo'), ('pswd', 1234), ('id', 37)])
